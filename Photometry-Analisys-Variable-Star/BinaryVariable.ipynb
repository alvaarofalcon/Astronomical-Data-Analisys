# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ap = [10, 15, 17, 18, 19, 20, 21, 23, 25, 30, 35, 40, 45, 50, 55, 60]
err_flux_rel_2 = [337.8, 393.3, 398.2, 397.6, 396.7, 394.7, 394.7, 387.2, 382.5, 357.2, 330.2, 303.3, 278.5, 255.2, 233.7, 214.6]
nparr = np.array(err_flux_rel_inv)

# %%
plt.scatter(ap, err_flux_rel_inv)
plt.plot(ap, err_flux_rel_inv)
plt.xlabel('Aperture')
plt.ylabel('1/Relative error of the flux')
# Out:
# Text(0, 0.5, '1/Relative error of the flux')

# %%
chi_2_dof = np.array([44.4, 25.7, 21.5, 19.9, 18.1, 16.8, 15.7, 14.4, 14.09, 13.27, 11.84, 10.49, 9.58, 8.99, 8.83, 8.11])
sqrt_chi = np.sqrt(chi_2_dof)

# %%
plt.figure(figsize=(7,10))

plt.subplot(2,1,1)
plt.scatter(ap, (1/nparr))
plt.plot(ap, 1/nparr)
plt.axvline(x=17, color='r', linestyle='--')
plt.xlabel('Aperture')
plt.ylabel('Relative error of the flux')


plt.subplot(2,1,2)
plt.scatter(ap, (1/nparr)*sqrt_chi)
plt.plot(ap, (1/nparr)*sqrt_chi)
plt.axvline(x=23, color='r', linestyle='--')
plt.xlabel('Aperture')
plt.ylabel('Relative error of the flux * sqrt(chi**2/dof)')
# Out:
# Text(0, 0.5, 'Relative error of the flux * sqrt(chi**2/dof)')

# %%
way = (1/nparr)*sqrt_chi
way
# Out:
# array([0.01972567, 0.01288969, 0.01164442, 0.01121967, 0.0107245 ,
#        0.01038455, 0.01003882, 0.00980045, 0.0098135 , 0.01019821,
#        0.01042075, 0.01067862, 0.01111367, 0.01174895, 0.01271515,
#        0.0132703 ])
